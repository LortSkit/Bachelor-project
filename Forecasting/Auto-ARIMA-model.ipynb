# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from contextlib import redirect_stdout

# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,3)

from pmdarima.arima import auto_arima, ADFTest

from sklearn.metrics import mean_squared_error

# %%
pf = pd.read_csv('pf_filled.csv')
cf = pd.read_csv('cf_filled.csv')

arr = pf[['Time','prod_k28']].set_index(pd.to_datetime(pf['Time']))
arr = arr.drop(['Time'],axis=1)

# %%
i = 0
j = 3000

test_ = pd.DataFrame()
pred_ = pd.DataFrame()

mse = []

while j <(len(arr)-24):
    train = arr[i:j]
    test = arr[j:(j+24)]
    
    arima_model = auto_arima(train, start_p=0, d=1, start_q=0, 
                        max_p = 5, max_d=5, max_q=5, start_P=0,
                        D=1, start_Q=0, m=24, seasonal=True, 
                        error_action='warn', trace=True, supress_warning=True,
                        stepwise=True, random_state=20, n_fits=50)
    
    pred = arima_model.predict(n_periods=24)    
    mse.append(mean_squared_error(test['prod_k28'],pred))
    
    test_ = test_.append(test)
    pred_ = pred_.append(pd.DataFrame(pred))
    pred_ = pred_.set_index(test_.index)
    
    test_.to_csv('test_.csv')
    pred_.to_csv('pred_.csv')
    
    plt.plot(test_)
    plt.plot(pred_)
    plt.show()
    
    plt.plot(np.arange(0,len(mse)), mse)
    plt.show()
    
    i +=24
    j +=24
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[24]             : AIC=10811.379, Time=0.24 sec
#  ARIMA(1,1,0)(1,1,0)[24]             : AIC=10058.569, Time=1.60 sec
#  ARIMA(0,1,1)(0,1,1)[24]             : AIC=inf, Time=4.34 sec
#  ARIMA(1,1,0)(0,1,0)[24]             : AIC=10811.387, Time=0.48 sec
#  ARIMA(1,1,0)(2,1,0)[24]             : AIC=9759.412, Time=5.06 sec
#  ARIMA(1,1,0)(2,1,1)[24]             : AIC=inf, Time=18.96 sec
#  ARIMA(1,1,0)(1,1,1)[24]             : AIC=inf, Time=6.84 sec
#  ARIMA(0,1,0)(2,1,0)[24]             : AIC=9757.651, Time=6.45 sec
#  ARIMA(0,1,0)(1,1,0)[24]             : AIC=10059.234, Time=2.45 sec
#  ARIMA(0,1,0)(2,1,1)[24]             : AIC=inf, Time=18.43 sec
#  ARIMA(0,1,0)(1,1,1)[24]             : AIC=inf, Time=6.63 sec
#  ARIMA(0,1,1)(2,1,0)[24]             : AIC=9759.331, Time=7.92 sec
#  ARIMA(1,1,1)(2,1,0)[24]             : AIC=inf, Time=70.42 sec
#  ARIMA(0,1,0)(2,1,0)[24] intercept   : AIC=9759.651, Time=11.33 sec
#
# Best model:  ARIMA(0,1,0)(2,1,0)[24]
# Total fit time: 161.180 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[24]             : AIC=10893.688, Time=0.28 sec
#  ARIMA(1,1,0)(1,1,0)[24]             : AIC=10136.022, Time=2.34 sec
#  ARIMA(0,1,1)(0,1,1)[24]             : AIC=inf, Time=4.51 sec
#  ARIMA(1,1,0)(0,1,0)[24]             : AIC=10891.598, Time=0.41 sec
#  ARIMA(1,1,0)(2,1,0)[24]             : AIC=9831.243, Time=4.57 sec
#  ARIMA(1,1,0)(2,1,1)[24]             : AIC=inf, Time=19.49 sec
#  ARIMA(1,1,0)(1,1,1)[24]             : AIC=inf, Time=7.47 sec
#  ARIMA(0,1,0)(2,1,0)[24]             : AIC=9830.403, Time=5.04 sec
#  ARIMA(0,1,0)(1,1,0)[24]             : AIC=10138.988, Time=1.45 sec
#  ARIMA(0,1,0)(2,1,1)[24]             : AIC=inf, Time=16.08 sec
#  ARIMA(0,1,0)(1,1,1)[24]             : AIC=inf, Time=4.96 sec
#  ARIMA(0,1,1)(2,1,0)[24]             : AIC=9830.848, Time=6.52 sec
#  ARIMA(1,1,1)(2,1,0)[24]             : AIC=inf, Time=62.96 sec
#  ARIMA(0,1,0)(2,1,0)[24] intercept   : AIC=9832.403, Time=16.28 sec
#
# Best model:  ARIMA(0,1,0)(2,1,0)[24]
# Total fit time: 152.380 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[24]             : AIC=10956.959, Time=0.36 sec
#  ARIMA(1,1,0)(1,1,0)[24]             : AIC=10155.680, Time=2.04 sec
#  ARIMA(0,1,1)(0,1,1)[24]             : AIC=inf, Time=5.28 sec
#  ARIMA(1,1,0)(0,1,0)[24]             : AIC=10952.587, Time=0.51 sec
#  ARIMA(1,1,0)(2,1,0)[24]             : AIC=9847.613, Time=4.94 sec
#  ARIMA(1,1,0)(2,1,1)[24]             : AIC=inf, Time=17.63 sec
#  ARIMA(1,1,0)(1,1,1)[24]             : AIC=inf, Time=5.99 sec
#  ARIMA(0,1,0)(2,1,0)[24]             : AIC=9847.033, Time=4.28 sec
#  ARIMA(0,1,0)(1,1,0)[24]             : AIC=10159.292, Time=1.30 sec
#  ARIMA(0,1,0)(2,1,1)[24]             : AIC=inf, Time=12.30 sec
#  ARIMA(0,1,0)(1,1,1)[24]             : AIC=inf, Time=5.56 sec
#  ARIMA(0,1,1)(2,1,0)[24]             : AIC=9847.135, Time=5.52 sec
#  ARIMA(1,1,1)(2,1,0)[24]             : AIC=inf, Time=87.19 sec
#  ARIMA(0,1,0)(2,1,0)[24] intercept   : AIC=9849.033, Time=18.14 sec
#
# Best model:  ARIMA(0,1,0)(2,1,0)[24]
# Total fit time: 171.087 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[24]             : AIC=10961.782, Time=0.34 sec
#  ARIMA(1,1,0)(1,1,0)[24]             : AIC=10179.907, Time=2.86 sec
#  ARIMA(0,1,1)(0,1,1)[24]             : AIC=inf, Time=7.75 sec
#  ARIMA(1,1,0)(0,1,0)[24]             : AIC=10956.823, Time=0.58 sec
#  ARIMA(1,1,0)(2,1,0)[24]             : AIC=9863.739, Time=7.19 sec
#  ARIMA(1,1,0)(2,1,1)[24]             : AIC=inf, Time=24.07 sec
#  ARIMA(1,1,0)(1,1,1)[24]             : AIC=inf, Time=9.48 sec
#  ARIMA(0,1,0)(2,1,0)[24]             : AIC=9863.554, Time=6.73 sec
#  ARIMA(0,1,0)(1,1,0)[24]             : AIC=10184.837, Time=2.14 sec
#  ARIMA(0,1,0)(2,1,1)[24]             : AIC=inf, Time=19.42 sec
#  ARIMA(0,1,0)(1,1,1)[24]             : AIC=inf, Time=6.74 sec
#  ARIMA(0,1,1)(2,1,0)[24]             : AIC=9863.130, Time=10.13 sec
#  ARIMA(0,1,1)(1,1,0)[24]             : AIC=10178.388, Time=5.98 sec
#  ARIMA(0,1,1)(2,1,1)[24]             : AIC=inf, Time=26.81 sec
#  ARIMA(0,1,1)(1,1,1)[24]             : AIC=inf, Time=11.36 sec
#  ARIMA(1,1,1)(2,1,0)[24]             : AIC=inf, Time=89.85 sec
#  ARIMA(0,1,2)(2,1,0)[24]             : AIC=9805.800, Time=8.56 sec
#  ARIMA(0,1,2)(1,1,0)[24]             : AIC=10149.080, Time=3.29 sec
#  ARIMA(0,1,2)(2,1,1)[24]             : AIC=inf, Time=24.86 sec
#  ARIMA(0,1,2)(1,1,1)[24]             : AIC=inf, Time=11.20 sec
#  ARIMA(1,1,2)(2,1,0)[24]             : AIC=inf, Time=89.04 sec
#  ARIMA(0,1,3)(2,1,0)[24]             : AIC=9782.711, Time=15.00 sec
#  ARIMA(0,1,3)(1,1,0)[24]             : AIC=10134.902, Time=5.50 sec
#  ARIMA(0,1,3)(2,1,1)[24]             : AIC=inf, Time=30.74 sec
#  ARIMA(0,1,3)(1,1,1)[24]             : AIC=inf, Time=12.24 sec
#  ARIMA(1,1,3)(2,1,0)[24]             : AIC=inf, Time=103.99 sec
#  ARIMA(0,1,4)(2,1,0)[24]             : AIC=9733.653, Time=18.45 sec
#  ARIMA(0,1,4)(1,1,0)[24]             : AIC=10079.361, Time=5.15 sec
#  ARIMA(0,1,4)(2,1,1)[24]             : AIC=inf, Time=34.80 sec
#  ARIMA(0,1,4)(1,1,1)[24]             : AIC=inf, Time=15.35 sec
#  ARIMA(1,1,4)(2,1,0)[24]             : AIC=inf, Time=97.16 sec
#  ARIMA(0,1,5)(2,1,0)[24]             : AIC=9681.149, Time=18.81 sec
#  ARIMA(0,1,5)(1,1,0)[24]             : AIC=10042.443, Time=6.33 sec
#  ARIMA(0,1,5)(2,1,1)[24]             : AIC=inf, Time=55.71 sec
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# statsmodels\tsa\statespace\_kalman_smoother.pyx in statsmodels.tsa.statespace._kalman_smoother.dKalmanSmoother.allocate_arrays()
#
# MemoryError: Unable to allocate 69.3 MiB for an array with shape (55, 55, 3001) and data type float64
